# %% [markdown]
# <a href="https://colab.research.google.com/github/Kimjisue/python/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def user_define(x,y):
  print(x,y,"is taking ECE30007")
  return x+ " "+y

string = user_define("Hanse","21100394")
print(string)
# Out:
# Hanse 21100394 is taking ECE30007
# Hanse 21100394

# %%
def foo():
  y = "local"
  print("local : ", y)
foo()
print(y)
# Out:
# local :  local
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-542a181e1a31> in <module>
#       3   print("local : ", y)
#       4 foo()
# ----> 5 print(y)
#
# NameError: name 'y' is not defined

# %%
x = "global"
def foo():
  print("x inside:",x)

foo()
print("x outside:",x)
# Out:
# x inside: global
# x outside: global

# %%
def sum(n):
  if n == 0:
    return 0
  return n*sum(n-1)
sum(10)
# Out:
# 0

# %%
def is_odd(num):
  if sum %2 == 0:
    return "Even"
   else:
     retuen

# %%
import numpy as np

a = no.

# %%
# import numpy as np
# import openpyxl # if you don’t’ have this, then pip install openpyxl first 
# file= openpyxl.load_workbook("data_set_train.xlsx") #assumingthatthefileisinthecurrentdirectory 
# ws = file.active
# data=[] # list type
# col_name=[] # list type
# for row in ws.iter_rows(max_row=1): #readthefirstrow
#     for cell in row:
#       col_name.append(cell.value)
# for row in ws.iter_rows(min_row=2): # read from the 2nd row 
#     one_line=[]
#     for cell in row:
#         one_line.append(cell.value)
#     data.append(one_line)

# years = range(2006,2018)
# for year in years:
#     year_str = str(year)
#     y_idx = [d[:4] == year_str for d in data[:,1]]
#     prices = data[y_idx,2].astype(float)

#     avg = np.mean(prices)
#     print(year_str + 'avg : %2f\t'%avg)

import numpy as np
import openpyxl

file = openpyxl.load_workbook("data_set_train.xlsx")
ws = file.active

data = []
col_name = []
for row in ws.iter_rows(max_row=1):
    for cell in row:
        col_name.append(cell.value)
for row in ws.iter_rows(min_row=2):
    one_line = []
    for cell in row:
        one_line.append(cell.value)
    data.append(one_line)

years = range(2006, 2018)
for year in years:
    year_str = str(year)
    y_idx = [d[1][:4] == year_str for d in data]
    prices = [d[2] for d in data if d[1][:4] == year_str]
    prices = np.array(prices, dtype=float)

    avg = np.mean(prices)
    print('{} avg: {:.2f}\t'.format(year_str, avg))
# Out:
# 2006 avg: 67076.58
# 2007 avg: 58405.72
# 2008 avg: 66136.67
# 2009 avg: 83060.50
# 2010 avg: 77282.03
# 2011 avg: 76748.97
# 2012 avg: 72714.52
# 2013 avg: 78839.02
# 2014 avg: 84002.70
# 2015 avg: 87213.44
# 2016 avg: 97149.95
# 2017 avg: 114656.79

# %%
# import numpy as np
# import openpyxl

# file = openpyxl.load_workbook("data_set_train.xlsx")
# ws = file.active

# data = []
# col_name = []
# for row in ws.iter_rows(max_row=1):
#     for cell in row:
#         col_name.append(cell.value)
# for row in ws.iter_rows(min_row=2):
#     one_line = []
#     for cell in row:
#         one_line.append(cell.value)
#     data.append(one_line)

# years = range(2006,2018)
# Qs = ['Q1','Q2','Q3','Q4']

# yq_list = []
# avg_list = []

# for year in years:
#   for quart in Qs:
#     yq = str(year)+quart
#     prices = data[data[:,1]==yq,2].astype(float)
#     if prices.shape[0] == 0: break

#     avg = np.mean(prices)
#     yq_list.append(yq)
#     avg_list.append(avg)

# for i, yq in enumerate(yq_list):
#   print(yq + 'avg : %.2\t'%avg_list[i], end='')
#   if(i+1)%4 == 0: print(' ')


import numpy as np
import openpyxl

file = openpyxl.load_workbook("data_set_train.xlsx")
ws = file.active

data = []
col_name = []
for row in ws.iter_rows(max_row=1):
    for cell in row:
        col_name.append(cell.value)
for row in ws.iter_rows(min_row=2):
    one_line = []
    for cell in row:
        one_line.append(cell.value)
    data.append(one_line)

years = range(2006,2018)
Qs = ['Q1','Q2','Q3','Q4']

yq_list = []
avg_list = []

for year in years:
    for quart in Qs:
        yq = str(year)+quart
        prices = [float(row[2]) for row in data if row[1] == yq]
        if not prices: continue
        
        avg = np.mean(prices)
        yq_list.append(yq)
        avg_list.append(avg)

for i, yq in enumerate(yq_list):
    print(yq + ' avg : %.2f\t' % avg_list[i], end='')
    if(i+1)%4 == 0: print(' ')
# Out:
# 2006Q1 avg : 65661.17	2006Q2 avg : 59592.49	2006Q3 avg : 62410.72	2006Q4 avg : 79588.83
# 2007Q1 avg : 47336.40	2007Q2 avg : 65344.61	2007Q3 avg : 58634.69	2007Q4 avg : 59687.89
# 2008Q1 avg : 63515.58	2008Q2 avg : 62458.85	2008Q3 avg : 72233.96	2008Q4 avg : 72608.62
# 2009Q1 avg : 85574.77	2009Q2 avg : 84314.42	2009Q3 avg : 83246.47	2009Q4 avg : 78589.30
# 2010Q1 avg : 80386.73	2010Q2 avg : 71885.82	2010Q3 avg : 72697.58	2010Q4 avg : 82475.98
# 2011Q1 avg : 77359.50	2011Q2 avg : 68071.24	2011Q3 avg : 78499.77	2011Q4 avg : 82607.86
# 2012Q1 avg : 73633.61	2012Q2 avg : 73102.35	2012Q3 avg : 78050.49	2012Q4 avg : 69313.77
# 2013Q1 avg : 77980.51	2013Q2 avg : 76391.85	2013Q3 avg : 76638.47	2013Q4 avg : 84570.14
# 2014Q1 avg : 84038.77	2014Q2 avg : 81931.40	2014Q3 avg : 79218.36	2014Q4 avg : 90134.39
# 2015Q1 avg : 76180.14	2015Q2 avg : 81677.28	2015Q3 avg : 98509.43	2015Q4 avg : 93279.71
# 2016Q1 avg : 87456.07	2016Q2 avg : 94492.74	2016Q3 avg : 104774.82	2016Q4 avg : 102236.93
# ...

# %%
# import matplotlib.pyplot as plt

# import numpy as np
# import openpyxl

# file = openpyxl.load_workbook("data_set_train.xlsx")
# ws = file.active

# data = []
# col_name = []
# for row in ws.iter_rows(max_row=1):
#     for cell in row:
#         col_name.append(cell.value)
# for row in ws.iter_rows(min_row=2):
#     one_line = []
#     for cell in row:
#         one_line.append(cell.value)
#     data.append(one_line)

# plt.figure(figsize=(100,40))
# y=list(mean_quaterly_price.values())
# x=list(mean_quaterly_price.keys())
# y1=list(quaterly__trading.values())
# x1=list(quaterly__trading.keys())
# plt.subplot(2,1,1)
# plt.xticks(fontsize=25)
# plt.yticks(fontsize=40)
# plt.bar(x1,y1,width=0.5,color='black',alpha=0.7)

# plt.subplot(2,1,2)
# plt.xticks(fontsize=25)
# plt.yticks(fontsize=40)
# plt.scatter(x,y,color='black')

# plt.show()

# 

import matplotlib.pyplot as plt
import numpy as np
import openpyxl

# Load data from Excel file

file = openpyxl.load_workbook("data_set_train.xlsx")
ws = file.active

data = []
col_name = []
for row in ws.iter_rows(max_row=1):
    for cell in row:
        col_name.append(cell.value)
for row in ws.iter_rows(min_row=2):
    one_line = []
    for cell in row:
        one_line.append(cell.value)
    data.append(one_line)

# Define variables for plotting
mean_quarterly_price = {d[0]: d[1] for d in data}
quarterly_trading = {d[0]: d[2] for d in data}

# Create subplots
fig, axs = plt.subplots(2, 1, figsize=(15, 15))

# Plot bar chart
axs[0].bar(quarterly_trading.keys(), quarterly_trading.values(), width=0.5, color='black', alpha=0.7)
axs[0].set_xlabel('Quarter', fontsize=20)
axs[0].set_ylabel('Trading', fontsize=20)
axs[0].set_title('Quarterly Trading', fontsize=25)

# Plot scatter plot
axs[1].scatter(mean_quarterly_price.keys(), mean_quarterly_price.values(), color='black')
axs[1].set_xlabel('Quarter', fontsize=20)
axs[1].set_ylabel('Price', fontsize=20)
axs[1].set_title('Mean Quarterly Price', fontsize=25)

plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 50669 (\N{HANGUL SYLLABLE YEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 50864 (\N{HANGUL SYLLABLE U}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.9/dist-packages/IPython/core/pylabtools.py:128: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
